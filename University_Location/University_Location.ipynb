# %%
import pandas as pd

df=pd.read_excel('고등교육기관 하반기 주소록(2022).xlsx')

def get_addrs(x):
    x1 = x.split(' ')
    return " ".join(x1[0:4])

df['도로명주소'] = df['주소'].apply(get_addrs)
df
# Out:
#        연도  학교종류                 학교명  \
# 0    2022  전문대학             동양미래대학교
# 1    2022  전문대학              명지전문대학
# 2    2022  전문대학             배화여자대학교
# 3    2022  전문대학             삼육보건대학교
# 4    2022  전문대학           서울여자간호대학교
# ..    ...   ...                 ...
# 435  2022  기능대학       한국폴리텍대학 구미캠퍼스
# 436  2022  기능대학  한국폴리텍 VII 대학 진주캠퍼스
# 437  2022  기능대학    한국폴리텍VII대학 창원캠퍼스
# 438  2022  기능대학       한국폴리텍대학 항공캠퍼스
# 439  2022  기능대학    한국폴리텍 I 대학 제주캠퍼스
#
#                                                 주소                 도로명주소
# 0                 서울특별시 구로구 경인로 445 (고척동, 동양미래대학교)     서울특별시 구로구 경인로 445
# 1                 서울특별시 서대문구 가좌로 134 (홍은동, 명지전문대학)    서울특별시 서대문구 가좌로 134
# 2    서울특별시 종로구 필운대로1길 34 (필운동, 배화여자대학교,배화여자중,고등학교)   서울특별시 종로구 필운대로1길 34
# 3                          서울특별시 동대문구 망우로 82 (휘경동)     서울특별시 동대문구 망우로 82
# 4               서울특별시 서대문구 간호대로 38 (홍제동, 서울여자간호대학)    서울특별시 서대문구 간호대로 38
# ..                                             ...                   ...
# 435         경상북도 구미시 수출대로3길 84 (공단동, 한국폴리텍대학구미캠퍼스)    경상북도 구미시 수출대로3길 84
# 436            경상남도 진주시 모덕로 299 (하대동, 한국폴리텍대학7캠퍼스)      경상남도 진주시 모덕로 299
# 437   경상남도 창원시 성산구 외동반림로 51-88 (중앙동, 한국폴리텍대학창원캠퍼스)    경상남도 창원시 성산구 외동반림로
# 438               경상남도 사천시 대학길 46 (이금동, 한국폴리텍항공대학)       경상남도 사천시 대학길 46
# 439      제주특별자치도 제주시 산천단동3길 2 (아라일동, 한국폴리택대학제주캠퍼스)  제주특별자치도 제주시 산천단동3길 2
#
# [440 rows x 5 columns]

# %%
import googlemaps
import pandas as pd

mykey = "AIzaSyB0HPuOS6EDcIEjxLIk7u08dtrkI98cGfQ"
maps = googlemaps.Client(key=mykey)

df=pd.read_excel('고등교육기관 하반기 주소록(2022).xlsx')

def get_addrs(x):
    x1 = x.split(' ')
    return " ".join(x1[0:4])

df['도로명주소'] = df['주소'].apply(get_addrs)

def geocoding_lat(addr):
    try:
        geo_location = maps.geocode(addr)[0].get('geometry')
        lat = geo_location['location']['lat']
        return lat
    except:
        return 0
    
def geocoding_lon(addr):
    try:
        geo_location = maps.geocode(addr)[0].get('geometry')
        lng =  geo_location['location']['lng']
        return lng
    except:
        return 0    

df['위도'] = df['도로명주소'].apply(geocoding_lat)
df['경도'] = df['도로명주소'].apply(geocoding_lon)
df
# Out:
#        연도  학교종류                 학교명  \
# 0    2022  전문대학             동양미래대학교
# 1    2022  전문대학              명지전문대학
# 2    2022  전문대학             배화여자대학교
# 3    2022  전문대학             삼육보건대학교
# 4    2022  전문대학           서울여자간호대학교
# ..    ...   ...                 ...
# 435  2022  기능대학       한국폴리텍대학 구미캠퍼스
# 436  2022  기능대학  한국폴리텍 VII 대학 진주캠퍼스
# 437  2022  기능대학    한국폴리텍VII대학 창원캠퍼스
# 438  2022  기능대학       한국폴리텍대학 항공캠퍼스
# 439  2022  기능대학    한국폴리텍 I 대학 제주캠퍼스
#
#                                                 주소                 도로명주소  \
# 0                 서울특별시 구로구 경인로 445 (고척동, 동양미래대학교)     서울특별시 구로구 경인로 445
# 1                 서울특별시 서대문구 가좌로 134 (홍은동, 명지전문대학)    서울특별시 서대문구 가좌로 134
# 2    서울특별시 종로구 필운대로1길 34 (필운동, 배화여자대학교,배화여자중,고등학교)   서울특별시 종로구 필운대로1길 34
# 3                          서울특별시 동대문구 망우로 82 (휘경동)     서울특별시 동대문구 망우로 82
# 4               서울특별시 서대문구 간호대로 38 (홍제동, 서울여자간호대학)    서울특별시 서대문구 간호대로 38
# ..                                             ...                   ...
# 435         경상북도 구미시 수출대로3길 84 (공단동, 한국폴리텍대학구미캠퍼스)    경상북도 구미시 수출대로3길 84
# 436            경상남도 진주시 모덕로 299 (하대동, 한국폴리텍대학7캠퍼스)      경상남도 진주시 모덕로 299
# 437   경상남도 창원시 성산구 외동반림로 51-88 (중앙동, 한국폴리텍대학창원캠퍼스)    경상남도 창원시 성산구 외동반림로
# 438               경상남도 사천시 대학길 46 (이금동, 한국폴리텍항공대학)       경상남도 사천시 대학길 46
# 439      제주특별자치도 제주시 산천단동3길 2 (아라일동, 한국폴리택대학제주캠퍼스)  제주특별자치도 제주시 산천단동3길 2
#
#             위도          경도
# 0    37.500542  126.867671
# 1    37.584498  126.925054
# 2    37.578332  126.966856
# 3    37.589321  127.064443
# 4    37.597517  126.947480
# ..         ...         ...
# 435  36.118481  128.373733
# 436  35.190164  128.127251
# 437  35.230290  128.673999
# 438  34.948327  128.107497
# 439  33.447636  126.561211
#
# [440 rows x 7 columns]

# %%
import googlemaps
import pandas as pd
import folium

mykey = "AIzaSyB0HPuOS6EDcIEjxLIk7u08dtrkI98cGfQ"
maps = googlemaps.Client(key=mykey)

mymap=folium.Map(location=[36, 127],zoom_start=7)

df=pd.read_excel('고등교육기관 하반기 주소록(2022).xlsx')

def get_addrs(x):
    x1 = x.split(' ')
    return " ".join(x1[0:4])

df['도로명주소'] = df['주소'].apply(get_addrs)

def geocoding_lat(addr):
    try:
        geo_location = maps.geocode(addr)[0].get('geometry')
        lat = geo_location['location']['lat']
        return lat
    except:
        return 0
    
def geocoding_lon(addr):
    try:
        geo_location = maps.geocode(addr)[0].get('geometry')
        lng =  geo_location['location']['lng']
        return lng
    except:
        return 0    

df['위도'] = df['도로명주소'].apply(geocoding_lat)
df['경도'] = df['도로명주소'].apply(geocoding_lon)

for i in range(len(df)):
    folium.Marker([float(df['위도'][i:i+1]),float(df['경도'][i:i+1])],popup=df['학교명'][i:i+1]).add_to(mymap)
    
for i in range(len(df)):
    folium.Marker([float(df.iloc[i,5]),float(df.iloc[i,6])],popup=df.iloc[i,2]).add_to(mymap)
mymap
# Out:
# C:\Users\oowgn\AppData\Local\Temp\ipykernel_3196\2338649323.py:38: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   folium.Marker([float(df['위도'][i:i+1]),float(df['경도'][i:i+1])],popup=df['학교명'][i:i+1],max_width=1000).add_to(mymap)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_36e468270067f767c1f2d784ebaaf4b8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_36e468270067f767c1f2d784ebaaf4b8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_36e468270067f767c1f2d784ebaaf4b8 = L.map(
#                 &quot;map_36e468270067f767c1f2d784ebaaf4b8&quot;,
#                 {
#                     center: [36.0, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_075e2df1efbaab61746475e18f7e4d83 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_36e468270067f767c1f2d784ebaaf4b8);
#
#
#             var marker_46d2b984f62922e1672e2dc189f33896 = L.marker(
#                 [37.5005419, 126.8676709],
#                 {&quot;maxWidth&quot;: 1000}
#             ).addTo(map_36e468270067f767c1f2d784ebaaf4b8);
#
#
#         var popup_70e15fcbd5ddea9082cb1161bc720764 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_50e5332ea7629298876691504403f4c6 = $(`&lt;div id=&quot;html_50e5332ea7629298876691504403f4c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0    동양미래대학교 Name: 학교명, dtype: object&lt;/div&gt;`)[0];
#                 popup_70e15fcbd5ddea9082cb1161bc720764.setContent(html_50e5332ea7629298876691504403f4c6);
#
#
#
#         marker_46d2b984f62922e1672e2dc189f33896.bindPopup(popup_70e15fcbd5ddea9082cb1161bc720764)
#         ;
#
#
#
#
#             var marker_fb3f3f49d6384e3c969385887d4d8035 = L.marker(
#                 [37.5844978, 126.9250537],
#                 {&quot;maxWidth&quot;: 1000}
#             ).addTo(map_36e468270067f767c1f2d784ebaaf4b8);
#
#
#         var popup_35efa9c8986e12b84ed0d2ce4ed69c89 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_54db601d2a60232ee81845128f233e52 = $(`&lt;div id=&quot;html_54db601d2a60232ee81845128f233e52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1    명지전문대학 Name: 학교명, dtype: object&lt;/div&gt;`)[0];
#                 popup_35efa9c8986e12b84ed0d2ce4ed69c89.setContent(html_54db601d2a60232ee81845128f233e52);
#
#
#
#         marker_fb3f3f49d6384e3c969385887d4d8035.bindPopup(popup_35efa9c8986e12b84ed0d2ce4ed69c89)
#         ;
#
#
#
#
#             var marker_f093fa2532b5f10c75c1dc86aa5c955c = L.marker(
#                 [37.578332, 126.966856],
#                 {&quot;maxWidth&quot;: 1000}
#             ).addTo(map_36e468270067f767c1f2d784ebaaf4b8);
#
#
#         var popup_bbb712ebff02c114b492a352db3556af = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6d04140ca6d8529b05cb124bff55096f = $(`&lt;div id=&quot;html_6d04140ca6d8529b05cb124bff55096f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2    배화여자대학교 Name: 학교명, dtype: object&lt;/div&gt;`)[0];
#                 popup_bbb712ebff02c114b492a352db3556af.setContent(html_6d04140ca6d8529b05cb124bff55096f);
#
#
#
#         marker_f093fa2532b5f10c75c1dc86aa5c955c.bindPopup(popup_bbb712ebff02c114b492a352db3556af)
#         ;
#
#
#
#
#             var marker_4d91f4e5a0fcf71c9c509a698fa9c469 = L.marker(
#                 [37.589321, 127.064443],
#                 {&quot;maxWidth&quot;: 1000}
#             ).addTo(map_36e468270067f767c1f2d784ebaaf4b8);
#
#
#         var popup_d956bb97953d9d6ff4a7062006f83184 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cded408d98276a1e1e82392d42627145 = $(`&lt;div id=&quot;html_cded408d98276a1e1e82392d42627145&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3    삼육보건대학교 Name: 학교명, dtype: object&lt;/div&gt;`)[0];
#                 popup_d956bb97953d9d6ff4a7062006f83184.setContent(html_cded408d98276a1e1e82392d42627145);
#
#
#
#         marker_4d91f4e5a0fcf71c9c509a698fa9c469.bindPopup(popup_d956bb97953d9d6ff4a7062006f83184)
#         ;
#
#
#
#
#             var marker_c4e933fcded95f6838fad5623d7d9712 = L.marker(
#                 [37.5975167, 126.9474798],
#                 {&quot;maxWidth&quot;: 1000}
#             ).addTo(map_36e468270067f767c1f2d784ebaaf4b8);
#
#
#         var popup_7ee05971303573b52b89202d2b657fc1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_87ac2046eb39c87d6a37500b4c30a4a3 = $(`&lt;div id=&quot;html_87ac2046eb39c87d6a37500b4c30a4a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4    서울여자간호대학교 Name: 학교명, dtype: object&lt;/div&gt;`)[0];
#                 popup_7ee05971303573b52b89202d2b657fc1.setContent(html_87ac2046eb39c87d6a37500b4c30a4a3);

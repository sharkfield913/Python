# %%
import googlemaps
import pandas as pd
import folium

mykey = "AIzaSyB0HPuOS6EDcIEjxLIk7u08dtrkI98cGfQ"
maps = googlemaps.Client(key=mykey)

mymap=folium.Map(location=[36, 127],zoom_start=7)

df=pd.read_excel('고등교육기관 하반기 주소록(2022).xlsx')

def get_addrs(x):
    x1 = x.split(' ')
    return " ".join(x1[0:4])

df['도로명주소'] = df['주소'].apply(get_addrs)

def geocoding_lat(addr):
    try:
        geo_location = maps.geocode(addr)[0].get('geometry')
        lat = geo_location['location']['lat']
        return lat
    except:
        return 0
    
def geocoding_lon(addr):
    try:
        geo_location = maps.geocode(addr)[0].get('geometry')
        lng =  geo_location['location']['lng']
        return lng
    except:
        return 0    

df['위도'] = df['도로명주소'].apply(geocoding_lat)
df['경도'] = df['도로명주소'].apply(geocoding_lon)

for i in range(len(df)):
    folium.Marker([float(df['위도'][i:i+1]),float(df['경도'][i:i+1])],popup='<pre>df['학교명'][i:i+1]</pre>').add_to(mymap)
    
for i in range(len(df)):
    folium.Marker([float(df.iloc[i,5]),float(df.iloc[i,6])],popup=df.iloc[i,2]).add_to(mymap)
mymap
# Out:
# C:\Users\oowgn\AppData\Local\Temp\ipykernel_3044\354381875.py:38: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   folium.Marker([float(df['위도'][i:i+1]),float(df['경도'][i:i+1])],popup=df['학교명'][i:i+1]).add_to(mymap)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_39a9c898d842f30ba06b21f5f24a5678 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_39a9c898d842f30ba06b21f5f24a5678&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_39a9c898d842f30ba06b21f5f24a5678 = L.map(
#                 &quot;map_39a9c898d842f30ba06b21f5f24a5678&quot;,
#                 {
#                     center: [36.0, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_76c904416d1274338f09864909003b8a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_39a9c898d842f30ba06b21f5f24a5678);
#
#
#             var marker_e8c49b94c6d50b7cd842ab31714abbf3 = L.marker(
#                 [37.5005419, 126.8676709],
#                 {}
#             ).addTo(map_39a9c898d842f30ba06b21f5f24a5678);
#
#
#         var popup_05b5a69d13860754e69dec5a8a1d44cc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a040d2b1a145fb0c29b18f84fb0b9666 = $(`&lt;div id=&quot;html_a040d2b1a145fb0c29b18f84fb0b9666&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0    동양미래대학교 Name: 학교명, dtype: object&lt;/div&gt;`)[0];
#                 popup_05b5a69d13860754e69dec5a8a1d44cc.setContent(html_a040d2b1a145fb0c29b18f84fb0b9666);
#
#
#
#         marker_e8c49b94c6d50b7cd842ab31714abbf3.bindPopup(popup_05b5a69d13860754e69dec5a8a1d44cc)
#         ;
#
#
#
#
#             var marker_b2c79dc6d695a2cbdb11ae214a98c868 = L.marker(
#                 [37.5844978, 126.9250537],
#                 {}
#             ).addTo(map_39a9c898d842f30ba06b21f5f24a5678);
#
#
#         var popup_da65974b753f11892292396028a8d818 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_83f90f3aa091f591a9b5d35415439ed5 = $(`&lt;div id=&quot;html_83f90f3aa091f591a9b5d35415439ed5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1    명지전문대학 Name: 학교명, dtype: object&lt;/div&gt;`)[0];
#                 popup_da65974b753f11892292396028a8d818.setContent(html_83f90f3aa091f591a9b5d35415439ed5);
#
#
#
#         marker_b2c79dc6d695a2cbdb11ae214a98c868.bindPopup(popup_da65974b753f11892292396028a8d818)
#         ;
#
#
#
#
#             var marker_aeeb6c4a5621a53f4a0e2f69578c3548 = L.marker(
#                 [37.578332, 126.966856],
#                 {}
#             ).addTo(map_39a9c898d842f30ba06b21f5f24a5678);
#
#
#         var popup_cde0549cd7c713da54c6345f0b47db27 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ce8cdc5d5106a3193bd9d03bfa6f7b43 = $(`&lt;div id=&quot;html_ce8cdc5d5106a3193bd9d03bfa6f7b43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2    배화여자대학교 Name: 학교명, dtype: object&lt;/div&gt;`)[0];
#                 popup_cde0549cd7c713da54c6345f0b47db27.setContent(html_ce8cdc5d5106a3193bd9d03bfa6f7b43);
#
#
#
#         marker_aeeb6c4a5621a53f4a0e2f69578c3548.bindPopup(popup_cde0549cd7c713da54c6345f0b47db27)
#         ;
#
#
#
#
#             var marker_3c1de66861daa10b8e120d5d77dbd368 = L.marker(
#                 [37.589321, 127.064443],
#                 {}
#             ).addTo(map_39a9c898d842f30ba06b21f5f24a5678);
#
#
#         var popup_afe4d48cf4a6a1d060a5886aae939d2d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ccb0b61c917ae667beacee7a08a192a8 = $(`&lt;div id=&quot;html_ccb0b61c917ae667beacee7a08a192a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3    삼육보건대학교 Name: 학교명, dtype: object&lt;/div&gt;`)[0];
#                 popup_afe4d48cf4a6a1d060a5886aae939d2d.setContent(html_ccb0b61c917ae667beacee7a08a192a8);
#
#
#
#         marker_3c1de66861daa10b8e120d5d77dbd368.bindPopup(popup_afe4d48cf4a6a1d060a5886aae939d2d)
#         ;
#
#
#
#
#             var marker_42995da7db390cd96c5ed42864176508 = L.marker(
#                 [37.5975167, 126.9474798],
#                 {}
#             ).addTo(map_39a9c898d842f30ba06b21f5f24a5678);
#
#
#         var popup_9b8d8b3657e2a087927cd0b8421345f0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9b90b350a1f8658b9a50b6e992f9f2e0 = $(`&lt;div id=&quot;html_9b90b350a1f8658b9a50b6e992f9f2e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4    서울여자간호대학교 Name: 학교명, dtype: object&lt;/div&gt;`)[0];
#                 popup_9b8d8b3657e2a087927cd0b8421345f0.setContent(html_9b90b350a1f8658b9a50b6e992f9f2e0);
#
#
#
#         marker_42995da7db390cd96c5ed42864176508.bindPopup(popup_9b8d8b3657e2a087927cd0b8421345f0)
#         ;
